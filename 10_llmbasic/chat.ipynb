# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# .env を読み込む
load_dotenv()

# OpenAI APIクライアントを生成（.env のキーを使う）
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# モデル名
MODEL_NAME = "gpt-4o-mini"

print("設定完了:", MODEL_NAME)
# Out:
# 設定完了: gpt-4o-mini

# %%
# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ]
)

# レスポンスの表示
pprint(vars(response))
# Out:
# {'_request_id': 'req_8d8ed28f8e854fdb8700cf3cdcd5c0a1',
#  'choices': [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='言語モデルを使う上でのポイントはいくつかあります。以下に主要な点を挙げます。\n\n1. **明確な質問や指示**: モデルに対して明確で具体的な質問や指示をすることで、より精度の高い応答を得やすくなります。曖昧な表現は避け、目的をはっきりさせることが重要です。\n\n2. **コンテキストの提供**: 必要に応じて背景情報や文脈を提供することで、モデルはより適切な回答を生成できます。特に、専門的な内容や特定の状況についての質問では、そのコンテキストが重要です。\n\n3. **フィードバックの活用**: モデルの応答から得られる情報を活用し、次の質問や指示を調整することで、より良い結果を引き出すことができます。\n\n4. **情報の確認**: モデルが提供する情報は必ずしも正確であるとは限りません。重要な決定を行う際には、他の信頼できる情報源と照らし合わせて確認することが重要です。\n\n5. **倫理的な利用**: 言語モデルを使用する際は、倫理的な側面に注意を払いましょう。誤情報の拡散や偏見の助長を避けるために、慎重に利用することが求められます。\n\n6. **限界の理解**: 言語モデルには限界があります。場合によっては、適切な応答を生成できないことや、特定のトピックに対する知識が不足していることがあります。使用する際はその限界を理解し、適切に対応することが重要です。\n\nこれらのポイントを考慮に入れることで、言語モデルをより効果的に活用できるでしょう。', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))],
#  'created': 1765073421,
#  'id': 'chatcmpl-CjyW5uQI61wSkwOY4R3cdY3p5ewsS',
#  'model': 'gpt-4o-mini-2024-07-18',
#  'object': 'chat.completion',
#  'service_tier': 'default',
#  'system_fingerprint': 'fp_eca0ce8298',
#  'usage': CompletionUsage(completion_tokens=440, prompt_tokens=18, total_tokens=458, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))}

# %%
# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 言語モデルを使う上でのポイントはいくつかあります。以下に主要な点を挙げます。
#
# 1. **明確な質問や指示**: モデルに対して明確で具体的な質問や指示をすることで、より精度の高い応答を得やすくなります。曖昧な表現は避け、目的をはっきりさせることが重要です。
#
# 2. **コンテキストの提供**: 必要に応じて背景情報や文脈を提供することで、モデルはより適切な回答を生成できます。特に、専門的な内容や特定の状況についての質問では、そのコンテキストが重要です。
#
# 3. **フィードバックの活用**: モデルの応答から得られる情報を活用し、次の質問や指示を調整することで、より良い結果を引き出すことができます。
#
# 4. **情報の確認**: モデルが提供する情報は必ずしも正確であるとは限りません。重要な決定を行う際には、他の信頼できる情報源と照らし合わせて確認することが重要です。
#
# 5. **倫理的な利用**: 言語モデルを使用する際は、倫理的な側面に注意を払いましょう。誤情報の拡散や偏見の助長を避けるために、慎重に利用することが求められます。
#
# 6. **限界の理解**: 言語モデルには限界があります。場合によっては、適切な応答を生成できないことや、特定のトピックに対する知識が不足していることがあります。使用する際はその限界を理解し、適切に対応することが重要です。
#
# これらのポイントを考慮に入れることで、言語モデルをより効果的に活用できるでしょう。

# %%
# 役割や前提の設定
role = "あなたはマーケティング分野に精通したビジネスコンサルタントです。企業の成長をサポートするために、効果的なマーケティング戦略を提供します。"

# メッセージの設定
message = "新製品の発売に向けた効果的なマーケティング戦略を教えてください。"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": role},
        {"role": "user", "content": message},
    ],
)

# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# 新製品の発売に向けた効果的なマーケティング戦略には、以下のステップを考慮することが重要です。
#
# ### 1. ターゲット市場の明確化
# - **市場調査**: ターゲットとなる顧客層のニーズや嗜好、競合の状況を把握。
# - **ペルソナ作成**: 具体的な顧客像を作成し、それに基づくコミュニケーション戦略を策定。
#
# ### 2. USP（ユニーク・セリング・プロポジション）の明確化
# - 新製品の特長や利点を明確にし、競合と差別化するポイントを強調。
#
# ### 3. プロモーション計画
# - **ティーザーキャンペーン**: 発売前に関心を高めるためのティザー広告やSNSキャンペーンを実施。
# - **インフルエンサーの活用**: 業界のインフルエンサーと提携し、製品を紹介してもらう。
# - **サンプル提供**: 潜在顧客に試してもらう機会を提供し、口コミを促進。
#
# ### 4. マルチチャネル戦略
# - **オンラインマーケティング**: SNS、メールマーケティング、SEO対策を通じて、広範囲にリーチ。
# - **オフラインマーケティング**: 店舗イベントやポップアップショップの開催で、直接顧客と接触。
#
# ### 5. 発売イベントの実施
# - 発売日には特別イベントを開催し、メディアを招待して報道を促進する。
# - 顧客参加型のアクティビティを通じて、製品の体験を提供。
#
# ### 6. フィードバックの収集
# - 発売後に顧客からのフィードバックを積極的に集め、次の施策に反映。
# - 顧客レビューや評価をマーケティングに活用し、信頼を築く。
#
# ### 7. 継続的なマーケティング活動
# - 認知度を維持するために、定期的にコンテンツを更新し、ブランドのストーリーを伝え続ける。
# - クロスセル・アップセルを促進し、顧客のロイヤリティを高める。
#
# ### 8. KPIの設定と評価
# - 各段階での成果を測定するためのKPI（重要業績評価指標）を設定し、戦略の効果を定期的に評価。
#
# これらのステップを組み合わせて、効果的な新製品のマーケティング戦略を構築することが重要です。マーケティング活動は柔軟に調整し、顧客の反応に応じて改善を続けることが成功の鍵となります。

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    temperature=1.4,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# もちろんです！日本には多くの魅力がありますので、いくつかを挙げてみます。
#
# ### 1. 豊かな歴史と文化
# 日本は、何千年にもわたる歴史を持ち、様々な文化が栄えてきました。例えば、古代の神社やお寺、 castlesや伝統的な町並みなどがあります。京都の金閣寺や奈良の東大寺
# --------------------
# もちろんです！日本にはたくさんの魅力がありますので、いくつかを紹介します。
#
# 1. **歴史的な文化遺産**: 日本は数千年の歴史を持ち、古い神社やお寺（例えば、京都の金閣寺や清水寺）、歴史的な城（松本城や姫路城）が多く存在します。
#
# 2. **自然の美**: 四季の
# --------------------
# 日本には多様な魅力があります。その一部をご紹介します。
#
# ### 1. 自然の美しさ
# 日本は四季折々の美しい風景が楽しめる国です。春には桜、夏には緑豊かな山々、秋には紅葉、冬には雪景色と、それぞれの季節に特有の美しさがあります。
#
# ### 2. 伝統文化
# 日本は豊かな伝統文化

# %%
# 出力の多様性★
message = "円周率を出すPythonのコードを書いて"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    temperature=1.4,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# 円周率（π）を計算する方法はいくつかあります。以下は、そのうちのいくつかの基本的な方法を示すPythonのコード例です。
#
# ### 方法1: モンテカルロ法を使って円周率を計算
#
# ```python
# import random
#
# def calculate_pi_monte_carlo(num_samples):
#     inside_circle = 0
#
#     for _ in range(num_samples):
#         x = random.uniform(-1,
# --------------------
# 円周率（π）を求めるためのPythonコードにはいくつかの方法があります。以下では、有名な「モンテカルロ法」を用いた方法と、慣用的なアルゴリズム（ライプニッツの公式）を使った方法を紹介します。
#
# ### 1. モンテカルロ法
#
# モンテカルロ法では、ランダムな点を平面にプロットし、
# --------------------
# 円周率を求めるためのPythonのコードの一例として、モンテカルロ法を使用する方法を紹介します。モンテカルロ法は、ランダムな点を使って円の面積を近似し、その結果を円周率として導出します。
#
# 以下にその実装を示します：
#
# ```python
# import random
#
# def calculate_pi(num_samples):
#     inside_circle = 0
#
#     for _ in range(num

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    temperature=0.0,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# もちろんです！日本は多様な文化、歴史、自然の美しさが融合した魅力的な国です。以下にいくつかのポイントを紹介します。
#
# ### 1. 文化と伝統
# - **祭り**: 日本各地で行われる伝統的な祭り（例：祇園祭、ねぶた祭り）は、地域の文化や歴史を体験できる素晴らしい機
# --------------------
# もちろんです！日本は多様な文化、歴史、自然、美食などが魅力的な国です。以下にいくつかのポイントを紹介します。
#
# ### 1. 文化と伝統
# - **祭り**: 日本各地で行われる伝統的な祭り（例：祇園祭、ねぶた祭り）は、地域の文化や歴史を感じることができます。
# - **茶道**:
# --------------------
# もちろんです！日本は多様な文化、歴史、自然、美食などが魅力的な国です。以下にいくつかのポイントを紹介します。
#
# ### 1. 文化と伝統
# - **祭り**: 日本各地で行われる伝統的な祭り（例：祇園祭、ねぶた祭り）は、地域の文化や歴史を感じることができます。
# - **茶道**:

# %%
import tiktoken
from tiktoken.core import Encoding

# OpenAI APIの特定のモデルに対応するトークナイザーを取得
encoding: Encoding = tiktoken.encoding_for_model(MODEL_NAME) # o200k_base

# テキストをトークンIDのリストに変換
tokens = encoding.encode("こんにちは！")
tokens_count = len(tokens)

# トークンの長さとトークンIDを表示
print(f"{tokens_count=}")
print(f"{tokens=}")
# Out:
# tokens_count=2
# tokens=[95839, 3393]

# %%
# トークンの選択度合い
message = """
AさんとBさんで会話してください。
A:あ、Bさんだ。
B:
"""

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    max_tokens=100,
    n=3,
    logit_bias = {95839:8, 3393:8}
)

# 結果を表示
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# B:こんにちは！Aさん、どうしていたの？
# --------------------
# B:こんにちは、Aさん！お元気ですか？
# --------------------
# B:こんにちは！Aさん、最近どうですか？

# %%
# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
stream = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    stream=True,
)

for chunk in stream:
    if chunk.choices:
        if chunk.choices[0].delta.content is not None:
            print(chunk.choices[0].delta.content, end="")
# Out:
# 言語モデルを効果的に活用するためのポイントはいくつかあります。以下にいくつか挙げます。
#
# 1. **明確なプロンプトを使用する**: 言語モデルに対する質問や指示はできるだけ具体的にすることが重要です。具体的な情報を求めることで、より正確で有用な回答を得られます。
#
# 2. **コンテキストを提供する**: モデルに与える情報が多いほど、適切な応答が得やすくなります。背景情報や目的を明示することで、モデルの理解を助けます。
#
# 3. **トーンやスタイルを指定する**: 回答が必要なトーンやスタイル（フォーマル、カジュアル、専門的ななど）を指定することで、実際の用途に合った応答を得ることができます。
#
# 4. **制約を設ける**: 特定の条件や制約を設けることで、精度の高い回答が得られる場合があります。例えば、「簡潔に答えてください」と指示することでより短い回答が得られます。
#
# 5. **繰り返しや修正を活用する**: 初回の回答が期待通りでない場合、質問を再構成したり追加情報を提供したりして、再度問い合わせることで改善できることがあります。
#
# 6. **フィードバックを与える**: モデルの応答に対してフィードバックを行うことで、次回のやり取りに活かすことが可能です。良い応答に対してはその旨を伝え、必要な修正点を指摘することが重要です。
#
# 7. **限界を理解する**: 言語モデルには限界があり、常に正確な情報を提供するわけではありません。特に事実確認が必要な場合や、専門的な知識が求められる場合は、他の情報源を参照するようにしましょう。
#
# 8. **倫理的な使用を心がける**: モデルを使用する際には、誤った情報や偏見を助長しないよう注意し、倫理的に責任のある利用を心がけることが大切です。
#
# これらのポイントを参考にしながら、言語モデルを上手に活用してみてください。
