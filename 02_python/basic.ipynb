# %%
# 名前と年齢を変数に格納
name="山田太郎"
age=25
next_age=age+1 # 来年の年齢

print("はじめまして、 ",name, "と申します。")
print("年齢は",age,"歳です。来年は",next_age,"歳になります。")
print("よろしくお願いします。")
# Out:
# はじめまして、  山田太郎 と申します。
# 年齢は 25 歳です。来年は 26 歳になります。
# よろしくお願いします。

# %%
# 名前と年齢を変数に格納
name="山田太郎"
age=25
next_age=age+1 # 来年の年齢

print(f"はじめまして、{name} と申します。")
print(f"年齢は{age}歳です。来年は{next_age}歳になります。")
print(f"よろしくお願いします。")
# Out:
# はじめまして、山田太郎 と申します。
# 年齢は25歳です。来年は26歳になります。
# よろしくお願いします。

# %%
# 各科目の点数を変数として定義
japanese = 85  # 国語
math = 90      # 数学
english = 75   # 英語

# 平均点を計算
average = (japanese + math + english) / 3

# 結果を表示
print("3科目の平均点は", average, "点です")
# Out:
# 3科目の平均点は 83.33333333333333 点です
